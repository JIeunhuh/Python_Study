# %%
import numpy as np
arr1 = np.array([1,2,3,4,5])
print(arr1.size)
# Out:
# 5

# %% [markdown]
# ### 배열 생성
#
# + arrange 함수
#
#   - 지정된 범위 내에서 균일한 간격으로 값을 생성하여 1차원 배열 반환
#   numpy.arrange(시작 값(default=0),종료 값,값 사이 간격(default=1),dtype)

# %% [markdown]
# ## __Matplotlib__
#
#   - 파이썬에서 데이터 시각화를 위한 일반적인 라이브러리
#   - numpy와 함께 사용
#   - 다양한 유형의 그래프 그리기 가능

# %%
import matplotlib.pyplot as plt
import numpy as np

# 기본 그래프

# x,y data 생성
x = np.arange(0,10,0.1)
y = np.sin(x)

# 선 그래프(그래프 스타일 변경 가능)
plt.plot(x,y,color='red',linestyle='--',linewidth=2)

# 그래프 타이틀과 축 라벨 설정
plt.title('Sine graph')
plt.xlabel('x')
plt.ylabel('y')

# 그래프 출력
plt.show()

# %%
# 산점도
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(100)
y = np.random.rand(100)

# 산점도 그리기
plt.scatter(x,y)

plt.title('Scatter Plot')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
